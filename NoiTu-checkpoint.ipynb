# %%
import re
import json
file_path1 = "VNESEcorpus.txt"
file_path2 = "VNTQcorpus-big.txt"
file_path3 = "VNTQcorpus-small.txt"
file_path4 = "vv30K.txt"
list_path=["VNESEcorpus.txt","VNTQcorpus-big.txt","VNTQcorpus-small.txt","vv30K.txt"]

dict_tu = {"tác giả":1}

def replace_special_characters(text):
    # Define the pattern to match special characters
    pattern = r'[!@#$%^&*(),.?":/\{}|<>1234567890-]'
    
    # Specify the replacement character
    replacement_char = ' '
    
    # Use re.sub() to replace special characters
    new_text = re.sub(pattern, replacement_char, text)
    
    return new_text

def xulycau(text_cau):
    text_cau_new=replace_special_characters(text_cau.lower())
    cau_tu=text_cau_new.split()
    for i in range(len(cau_tu)-1):
        j=i+1
        tu_moi=cau_tu[i]+' '+cau_tu[j]
        #print(tu_moi)
        if tu_moi in dict_tu:
            sl_tu=dict_tu[tu_moi]
            dict_tu[tu_moi] = sl_tu+1
        else:
            dict_tu[tu_moi] = 1
    return cau_tu
   
try:
    with open(file_path1, "r", encoding="utf-8") as file:
        lines = file.readlines()
        tong = 3
        i=0
        for line in lines:
            xulycau(line)
            if i<=tong:
                i=i + 1
            else:
                break
        print(dict_tu)
    with open(file_path2, "r", encoding="utf-8") as file:
        lines = file.readlines()
        tong = 3
        i=0
        for line in lines:
            xulycau(line)
            if i<=tong:
                i=i + 1
            else:
                break
        print(dict_tu)
    with open(file_path3, "r", encoding="utf-8") as file:
        lines = file.readlines()
        tong = 3
        i=0
        for line in lines:
            xulycau(line)
            if i<=tong:
                i=i + 1
            else:
                break
        print(dict_tu)
    with open(file_path4, "r", encoding="utf-8") as file:
        lines = file.readlines()
        tong = 3
        i=0
        for line in lines:
            xulycau(line)
            if i<=tong:
                i=i + 1
            else:
                break
        print(dict_tu)
except FileNotFoundError:
    print("File not found!")
except IOError:
    print("An error occurred while reading the file.")
    
json_data = json.dumps(dict_tu,ensure_ascii=False)

print(json_data)

with open("output.txt", "w", encoding="utf-8") as file:
    # Write the JSON data to the file
    file.write(json_data)
# Out:
# {'tác giả': 1, 'năm bản': 2, 'bản quyền': 4, 'quyền miễn': 2, 'miễn phí': 2, 'phí phần': 2, 'phần mềm': 7, 'mềm bảo': 4, 'bảo mật': 4, 'mật hàng': 2, 'hàng đầu': 3, 'đầu thủ': 1, 'thủ thuật': 2, 'thuật dân': 1, 'dân trí': 4, 'trí báo': 1, 'báo điện': 1, 'điện tử': 1, 'tử của': 1, 'của báo': 1, 'báo khuyến': 1, 'khuyến học': 1, 'học dân': 1, 'trí giao': 1, 'giao diện': 2, 'diện pda': 1, 'pda mua': 1, 'mua chung': 1, 'chung blog': 1, 'blog tấm': 1, 'tấm lòng': 1, 'lòng nhân': 1, 'nhân ái': 2, 'ái tuần': 1, 'tuần báo': 1, 'báo mua': 1, 'mua bán': 1, 'bán bé': 1, 'bé xinh': 1, 'xinh diễn': 1, 'diễn đàn': 1, 'đàn dân': 1, 'trí english': 1, 'english sự': 1, 'sự kiện': 1, 'kiện xã': 1, 'xã hội': 1, 'hội thế': 1, 'thế giới': 2, 'giới thể': 1, 'thể thao': 2, 'thao giáo': 1, 'giáo dục': 1, 'dục nhân': 1, 'ái kinh': 1, 'kinh doanh': 1, 'doanh văn': 1, 'văn hóa': 1, 'hóa pháp': 1, 'pháp luật': 1, 'luật nhịp': 1, 'nhịp sống': 1, 'sống trẻ': 1, 'trẻ tình': 1, 'tình yêu': 1, 'yêu sức': 1, 'sức khỏe
# ...

# %%
import re
import json
file_path1 = "VNESEcorpus.txt"
file_path2 = "VNTQcorpus-big.txt"
file_path3 = "VNTQcorpus-small.txt"
file_path4 = "vv30K.txt"
list_path=["VNESEcorpus.txt","VNTQcorpus-big.txt","VNTQcorpus-small.txt","vv30K.txt"]

dict_tu = {"tác giả":1}

def replace_special_characters(text):
    # Define the pattern to match special characters
    pattern = r'[!@#$%^&*(),.?":/\{}|<>1234567890-]'
    
    # Specify the replacement character
    replacement_char = ' '
    
    # Use re.sub() to replace special characters
    new_text = re.sub(pattern, replacement_char, text)
    
    return new_text

def xulycau(text_cau):
    text_cau_new=replace_special_characters(text_cau.lower())
    cau_tu=text_cau_new.split()
    for i in range(len(cau_tu)-1):
        j=i+1
        tu_moi=cau_tu[i]+' '+cau_tu[j]
        #print(tu_moi)
        if tu_moi in dict_tu:
            sl_tu=dict_tu[tu_moi]
            dict_tu[tu_moi] = sl_tu+1
        else:
            dict_tu[tu_moi] = 1
    return cau_tu
   
try:
    with open(file_path1, "r", encoding="utf-8") as file:
        lines = file.readlines()
        for line in lines:
            xulycau(line)
    with open(file_path2, "r", encoding="utf-8") as file:
        lines = file.readlines()
        for line in lines:
            xulycau(line)
    with open(file_path3, "r", encoding="utf-8") as file:
        lines = file.readlines()
        for line in lines:
            xulycau(line)
    with open(file_path4, "r", encoding="utf-8") as file:
        lines = file.readlines()
        for line in lines:
            xulycau(line)
except FileNotFoundError:
    print("File not found!")
except IOError:
    print("An error occurred while reading the file.")

for key, value in dict_tu.copy().items():
    if(value <=2):
        del dict_tu[key]

json_data = json.dumps(dict_tu,ensure_ascii=False)

#print(json_data)

with open("ds_tu.txt", "w", encoding="utf-8") as file:
    # Write the JSON data to the file
    file.write(json_data)
# Out:
# {'tác giả': 1, 'năm bản': 2, 'bản quyền': 4, 'quyền miễn': 2, 'miễn phí': 2, 'phí phần': 2, 'phần mềm': 7, 'mềm bảo': 4, 'bảo mật': 4, 'mật hàng': 2, 'hàng đầu': 3, 'đầu thủ': 1, 'thủ thuật': 2, 'thuật dân': 1, 'dân trí': 4, 'trí báo': 1, 'báo điện': 1, 'điện tử': 1, 'tử của': 1, 'của báo': 1, 'báo khuyến': 1, 'khuyến học': 1, 'học dân': 1, 'trí giao': 1, 'giao diện': 2, 'diện pda': 1, 'pda mua': 1, 'mua chung': 1, 'chung blog': 1, 'blog tấm': 1, 'tấm lòng': 1, 'lòng nhân': 1, 'nhân ái': 2, 'ái tuần': 1, 'tuần báo': 1, 'báo mua': 1, 'mua bán': 1, 'bán bé': 1, 'bé xinh': 1, 'xinh diễn': 1, 'diễn đàn': 1, 'đàn dân': 1, 'trí english': 1, 'english sự': 1, 'sự kiện': 1, 'kiện xã': 1, 'xã hội': 1, 'hội thế': 1, 'thế giới': 2, 'giới thể': 1, 'thể thao': 2, 'thao giáo': 1, 'giáo dục': 1, 'dục nhân': 1, 'ái kinh': 1, 'kinh doanh': 1, 'doanh văn': 1, 'văn hóa': 1, 'hóa pháp': 1, 'pháp luật': 1, 'luật nhịp': 1, 'nhịp sống': 1, 'sống trẻ': 1, 'trẻ tình': 1, 'tình yêu': 1, 'yêu sức': 1, 'sức khỏe
# ...
